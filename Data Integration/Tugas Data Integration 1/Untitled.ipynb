# %% [markdown]
# # TUGAS 1

# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv('G:\Kuliah\Data Mining\Data Integration\Tugas\Hearts Disease UCI 1.csv')
data2 = pd.read_csv('G:\Kuliah\Data Mining\Data Integration\Tugas\Hearts Disease UCI 2.csv')

data_complete = pd.merge(data1, data2, on='age')
data_complete
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      63    1   3       145   233    1        0      150      0      2.3
# 1      63    1   3       145   233    1        0      172      0      0.0
# 2      63    1   3       145   233    1        0      179      0      0.0
# 3      63    1   3       145   233    1        0      147      0      1.4
# 4      63    1   3       145   233    1        0      132      1      1.8
# 5      63    1   3       145   233    1        0      154      0      4.0
# 6      63    1   3       145   233    1        0      169      1      1.8
# 7      63    1   3       145   233    1        0      144      1      4.0
# 8      63    1   3       145   233    1        0      136      1      0.0
# 9      63    0   2       135   252    0        0      150      0      2.3
# 10     63    0   2       135   252    0        0      172      0      0.0
# 11     63    0   2       135   252    0        0      179      0      0.0
# ...

# %%
data3 = pd.read_csv('G:\Kuliah\Data Mining\Data Integration\Tugas\Heart Disease UCI 3.csv')
data4 = pd.read_csv('G:\Kuliah\Data Mining\Data Integration\Tugas\Heart Disease UCI 4.csv')
frame = [data3,data4]

result = pd.concat(frame)
result
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...
